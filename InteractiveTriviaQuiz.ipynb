# %% [markdown]
# # Project Title

# %% [markdown]
# Write a brief description of your project here.
#
# Note that projects should be self-sufficient, so make sure to provide enough information and context here for someone to understand what you are doing in your project, and why.

# %% [markdown]
# ## Project Code
#
# Demonstrate how your project works here! (If it doesn't work from the notebook, describe what graders should do to execute your project.)

# %%
import module # your module.py file

# %%
# Do a bunch of things.
module.play()
# Out:
#  Welcome to the Trivia Quiz Game!
# You'll be answering 5 questions.
#
# ----------------------------------------
#
# Question 1 of 5:
# What language is primarily spoken in Brazil?
#   1. Spanish
#   2. English
#   3. Portuguese
#   4. French
# Your answer (1-4):  3
# ✅ Correct!
#
# Question 2 of 5:
# What is 12 x 12?
#   1. 124
#   2. 144
#   3. 132
#   4. 148
# Your answer (1-4):  2
# ✅ Correct!
#
# Question 3 of 5:
# What is the capital of France?
#   1. Berlin
#   2. Madrid
#   3. Paris
#   4. Rome
# Your answer (1-4):  3
# ✅ Correct!
#
# Question 4 of 5:
# Which planet is known as the Red Planet?
#   1. Venus
#   2. Saturn
#   3. Jupiter
#   4. Mars
# Your answer (1-4):  4
# ✅ Correct!
#
# Question 5 of 5:
# What is the chemical symbol for water?
#   1. O2
#   2. CO2
#   3. H2O
#   4. HO
# Your answer (1-4):  3
# ✅ Correct!
#
# ----------------------------------------
#
# 🏆 Final Score: 5/5 (100.0%)
# 📝 Grade: A

# %% [markdown]
# #### Testing
#
# Run your tests. Sample code is provided below; you may need to edit this, depending upon how you've set up your tests.

# %%
# test it out
import unittest
import tests  # your tests.py file

unittest.main(tests.__name__, argv=[''], verbosity=2, exit=False)
# Out:
# test_all_correct (tests.TestCalculateScore.test_all_correct)
# All True results should give 100% and correct == total. ... ok
# test_all_incorrect (tests.TestCalculateScore.test_all_incorrect)
# All False results should give 0%. ... ok
# test_mixed_results (tests.TestCalculateScore.test_mixed_results)
# Mixed results should calculate the right percentage. ... ok
# test_raises_on_empty_list (tests.TestCalculateScore.test_raises_on_empty_list)
# Should raise ValueError for an empty list. ... ok
# test_returns_dict_with_correct_keys (tests.TestCalculateScore.test_returns_dict_with_correct_keys)
# Result should be a dict with 'correct', 'total', 'percentage'. ... ok
# test_single_correct (tests.TestCalculateScore.test_single_correct)
# Single correct answer should give 100%. ... ok
# test_correct_answer_returns_true (tests.TestCheckAnswer.test_correct_answer_returns_true)
# Correct answer index should return True. ... ok
# test_returns_bool_type (tests.TestCheckAnswer.test_returns_bool_type)
# Return value should be a bool. ... ok
# test_wrong_answer_returns_false (tests.TestCheckAnswer.test_wrong_answer_returns_false)
# Any wrong answer index should return False. ... ok
# test_a_grade (tests.TestGetGrade.test_a_grade)
# 90 and above should return 'A'. ... ok
# test_b_grade (tests.TestGetGrade.test_b_grade)
# 80-89.9 should return 'B'. ... ok
# test_c_grade (tests.TestGetGrade.test_c_grade)
# 70-79.9 should return 'C'. ... ok
# test_d_grade (tests.TestGetGrade.test_d_grade)
# 60-69.9 should return 'D'. ... ok
# test_f_grade (tests.TestGetGrade.test_f_grade)
# Below 60 should return 'F'. ... ok
# test_raises_on_invalid_percentage (tests.TestGetGrade.test_raises_on_invalid_percentage)
# Should raise ValueError for percentages outside [0, 100]. ... ok
# test_default_returns_five (tests.TestGetQuestions.test_default_returns_five)
# Default call should return 5 questions. ... ok
# test_each_question_has_four_choices (tests.TestGetQuestions.test_each_question_has_four_choices)
# Each question should have exactly 4 answer choices. ... ok
# test_no_shuffle_returns_same_order (tests.TestGetQuestions.test_no_shuffle_returns_same_order)
# With shuffle=False, order should be consistent (first n questions). ... ok
# test_questions_have_required_keys (tests.TestGetQuestions.test_questions_have_required_keys)
# Every question dict must have 'question', 'choices', and 'answer'. ... ok
# test_raises_value_error_for_too_many (tests.TestGetQuestions.test_raises_value_error_for_too_many)
# Should raise ValueError when n exceeds question bank size. ... ok
# test_raises_value_error_for_zero (tests.TestGetQuestions.test_raises_value_error_for_zero)
# Should raise ValueError when n=0. ... ok
# test_returns_correct_number (tests.TestGetQuestions.test_returns_correct_number)
# get_questions(n) should return exactly n questions. ... ok
#
# ----------------------------------------------------------------------
# Ran 22 tests in 0.063s
#
# OK

# %% [markdown]
# #### GenAI Statement
#
# I utilized the notes/lectures from class to implement each step into the code on my own. But whenever I got stuck (primarily debugging) I would ask AI to guide me into the right direction. All in all, I came to the answers on my own but if I had an issue that I could not find the answer to in lecture notes, I would have AI guide me to what was wrong. I would eplicitly say "Dont tell me the answer but guide me to it." Given the scale of my interactive trivia quiz this was imperative for the debugging process. I learned so much more about the code when I found the answer myself and not having AI explicitly telling me what was wrong. Applying what I learned in this course was far and away the most enojyable part of this project!

# %% [markdown]
# #### Extra Credit (*optional*)
#
# Replace all of this text with a brief explanation (~3 sentences) of:
# 1. Your Python Background: I took AP Principles of Computer Science in highschool but it was mostly block code with very little python at the very end. So coming into the course, my background in python was essentially at a novice level. This project allowed me to really show off what I learned!
# 2. How your project went above and beyond the requirements of the project and/or how you challenged yourself to learn something new with the final project: I added
